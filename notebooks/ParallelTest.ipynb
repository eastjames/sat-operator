# %%
import multiprocessing
import numpy as np

# %%
import time

# %%
def cubed(x):
    ret = x
    print(f'{ret} ')
    time.sleep(1)
    return

# %%
xx = np.arange(1000)

# %%
multiprocessing.cpu_count()
# Out:
# 32

# %%
import os

# %%
os.cpu_count()
# Out:
# 32

# %%
with open('test2.txt','a') as outf:
    print('test3',file=outf, flush=True)

# %%
with multiprocessing.Pool(processes = 32) as pool:
    res = pool.map(cubed, xx)
# Out:
# 48 8 0 40 32 16 56 24 64 72 80 88 96 104 112 128 136 120 144 152
# 160 168 176 184 192
#
#
# 200 208 216 224 232
#
# 240 248
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 49
# 9 1 41
#
#
# 33 17
# 57 25 65 73
#
# 81 89
# 105 97
# 113
# 137 129 121 145
# 161
# 153
#
# 169 177
# 185 193
# 201
# 209
#
# 225 217 233 241
# 249
#
#
#
#
#
#
#
#
#
#
#
# 50
# 10 2 42
#
#
# 34 18
# 58
# 26
# 66
# 74
#
# 82 90 106 98
#
# 114
#
# 138 130
# 146 122
#
# 162
#
# 154 178
# 170 186 194
# 210 202 226
# 218 234 250
# 242
#
#
#
#
#
#
#
#
# 51
# 11 3 43
#
#
# 35 19
# 59
# 27
# 67
# 75
#
# 83 91 99 107
#
# 115
#
# 131 139
# 147 123
#
# 163
#
# 155
# 179
# 171 187
# 195 203 211 227
#
# 219 251 235
# 243
#
#
#
#
#
#
# 52
# 12 4 44
#
#
# 36
# 20 60
# 28
# 68
# 76
#
# 84 92 108 100
#
#
# 116
# 132 140
# 148
# 124
# 164
#
# 156
# 180
# 172
# 188
# 196
# 212 204 228
# 252 220 236 244
#
#
#
#
#
#
# 53
# 13 5 45
#
#
# 37
# 21 61
# 29
# 69
# 77
#
# 85 93 109 101
#
# 117
#
# 141 133
# 149 125
#
# 165
#
# 157
# ...
